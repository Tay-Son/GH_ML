# %%
# Notebook 출력설정
# 주요 라이브러리 임포트

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns',2000)
pd.set_option('display.width', 2000)

# %matplotlib inline
import matplotlib.pylab as plt
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['axes.grid'] = True
import seaborn as sns

# %%
# 원본 데이터셋 로드
DIR_DATASET = "C:/Users/0stix/Datasets/"
NAME_PROJECT = "2203-kaggle-tps2203"

# %%
df_train = pd.read_csv(DIR_DATASET + NAME_PROJECT + '/train.csv', index_col='row_id')
df_test = pd.read_csv(DIR_DATASET + NAME_PROJECT + '/test.csv', index_col='row_id')
df_sub = pd.read_csv(DIR_DATASET + NAME_PROJECT + '/sample_submission.csv', index_col='row_id')

train = df_train
test = df_test

# %%
from pycaret.regression import *

# %%
import time

train['time'] = pd.to_datetime(train.time)
# delete official holiday                                                 
train['offical_holiday'] = train.time.dt.date.astype(str).str.contains('1991-05-27|1991-07-04|1991-09-02').astype('int')
train=train[train['offical_holiday']==0]
train=train.drop('offical_holiday',axis=1)
# train on data for Mondays to Thursdays and complete months only
train=train[(train.time.dt.weekday< 4) & (train.time.dt.month > 4)]     

def pre_process(df): 
    df['time'] = pd.to_datetime(df['time'])
    df['month']= df.time.dt.month
    df['day']= df.time.dt.dayofyear
    df['am'] = (df.time.dt.hour < 12) & (df.time.dt.hour >6)
    df['wkday'] = df.time.dt.weekday
    df['time']= (df.time.dt.hour-12)*3+df.time.dt.minute/20
    df['xydirday']= df.x.astype(str)+df.y.astype(str)+df.direction+df.day.astype(str)
    df['xydir'] = df.x.astype(str)+df.y.astype(str)+df.direction
    df['all']= df['xydir']+df.time.astype(str)
    
pre_process(train)
pre_process(test)

# calculate average traffic flow for each time of day 
mapper_avg = train[['all','congestion']].groupby(['all']).median().to_dict()['congestion']

train['avg']= train['all'].map(mapper_avg)
test['avg']= test['all'].map(mapper_avg)
train= train[train.time >=0]

# %%
reg = setup(data = train,
            target = 'congestion',
            session_id=999,
            data_split_shuffle = True, 
            create_clusters = False,
            fold_strategy = 'groupkfold',
            fold_groups = 'wkday',
            use_gpu = False,
            silent = True,
            fold=4,
            ignore_features = ['all','day','xydirday'],
            n_jobs = -1)
# Out:
# <style type="text/css">
# #T_8be98_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8be98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8be98_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8be98_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8be98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8be98_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8be98_row0_col1" class="data row0 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8be98_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8be98_row1_col1" class="data row1 col1" >congestion</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8be98_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_8be98_row2_col1" class="data row2 col1" >(193700, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8be98_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_8be98_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8be98_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_8be98_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8be98_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_8be98_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8be98_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_8be98_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8be98_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_8be98_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8be98_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_8be98_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8be98_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_8be98_row9_col1" class="data row9 col1" >(135589, 92)</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8be98_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_8be98_row10_col1" class="data row10 col1" >(58111, 92)</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8be98_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_8be98_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8be98_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_8be98_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8be98_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_8be98_row13_col1" class="data row13 col1" >GroupKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8be98_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_8be98_row14_col1" class="data row14 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8be98_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_8be98_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8be98_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_8be98_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8be98_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_8be98_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8be98_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_8be98_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8be98_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_8be98_row19_col1" class="data row19 col1" >11a9</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8be98_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_8be98_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8be98_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_8be98_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8be98_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_8be98_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8be98_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_8be98_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8be98_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_8be98_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_8be98_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_8be98_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_8be98_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_8be98_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_8be98_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_8be98_row27_col1" class="data row27 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_8be98_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_8be98_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_8be98_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_8be98_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8be98_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_8be98_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_8be98_row30_col1" class="data row30 col1

# %%
top_ = compare_models(sort = 'MAE', n_select=4, exclude = ['lar',  'rf', 'et', 'gbr'])
# Out:
# <style type="text/css">
# #T_7983f th {
#   text-align: left;
# }
# #T_7983f_row0_col0, #T_7983f_row0_col6, #T_7983f_row1_col0, #T_7983f_row1_col1, #T_7983f_row1_col2, #T_7983f_row1_col3, #T_7983f_row1_col4, #T_7983f_row1_col5, #T_7983f_row1_col6, #T_7983f_row2_col0, #T_7983f_row2_col1, #T_7983f_row2_col2, #T_7983f_row2_col3, #T_7983f_row2_col4, #T_7983f_row2_col5, #T_7983f_row2_col6, #T_7983f_row3_col0, #T_7983f_row3_col1, #T_7983f_row3_col2, #T_7983f_row3_col3, #T_7983f_row3_col4, #T_7983f_row3_col5, #T_7983f_row4_col0, #T_7983f_row4_col1, #T_7983f_row4_col2, #T_7983f_row4_col3, #T_7983f_row4_col4, #T_7983f_row4_col5, #T_7983f_row4_col6, #T_7983f_row5_col0, #T_7983f_row5_col1, #T_7983f_row5_col2, #T_7983f_row5_col3, #T_7983f_row5_col4, #T_7983f_row5_col5, #T_7983f_row5_col6, #T_7983f_row6_col0, #T_7983f_row6_col1, #T_7983f_row6_col2, #T_7983f_row6_col3, #T_7983f_row6_col4, #T_7983f_row6_col5, #T_7983f_row6_col6, #T_7983f_row7_col0, #T_7983f_row7_col1, #T_7983f_row7_col2, #T_7983f_row7_col3, #T_7983f_row7_col4, #T_7983f_row7_col5, #T_7983f_row7_col6, #T_7983f_row8_col0, #T_7983f_row8_col1, #T_7983f_row8_col2, #T_7983f_row8_col3, #T_7983f_row8_col4, #T_7983f_row8_col5, #T_7983f_row8_col6, #T_7983f_row9_col0, #T_7983f_row9_col1, #T_7983f_row9_col2, #T_7983f_row9_col3, #T_7983f_row9_col4, #T_7983f_row9_col5, #T_7983f_row9_col6, #T_7983f_row10_col0, #T_7983f_row10_col1, #T_7983f_row10_col2, #T_7983f_row10_col3, #T_7983f_row10_col4, #T_7983f_row10_col5, #T_7983f_row10_col6, #T_7983f_row11_col0, #T_7983f_row11_col1, #T_7983f_row11_col2, #T_7983f_row11_col3, #T_7983f_row11_col4, #T_7983f_row11_col5, #T_7983f_row11_col6, #T_7983f_row12_col0, #T_7983f_row12_col1, #T_7983f_row12_col2, #T_7983f_row12_col3, #T_7983f_row12_col4, #T_7983f_row12_col5, #T_7983f_row12_col6, #T_7983f_row13_col0, #T_7983f_row13_col1, #T_7983f_row13_col2, #T_7983f_row13_col3, #T_7983f_row13_col4, #T_7983f_row13_col5, #T_7983f_row13_col6, #T_7983f_row14_col0, #T_7983f_row14_col1, #T_7983f_row14_col2, #T_7983f_row14_col3, #T_7983f_row14_col4, #T_7983f_row14_col5, #T_7983f_row14_col6, #T_7983f_row15_col0, #T_7983f_row15_col1, #T_7983f_row15_col2, #T_7983f_row15_col3, #T_7983f_row15_col4, #T_7983f_row15_col5, #T_7983f_row15_col6 {
#   text-align: left;
# }
# #T_7983f_row0_col1, #T_7983f_row0_col2, #T_7983f_row0_col3, #T_7983f_row0_col4, #T_7983f_row0_col5, #T_7983f_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7983f_row0_col7, #T_7983f_row1_col7, #T_7983f_row2_col7, #T_7983f_row3_col7, #T_7983f_row4_col7, #T_7983f_row5_col7, #T_7983f_row6_col7, #T_7983f_row7_col7, #T_7983f_row8_col7, #T_7983f_row9_col7, #T_7983f_row10_col7, #T_7983f_row11_col7, #T_7983f_row12_col7, #T_7983f_row13_col7, #T_7983f_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7983f_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7983f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7983f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7983f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7983f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7983f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7983f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7983f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7983f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7983f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7983f_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_7983f_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_7983f_row0_col1" class="data row0 col1" >5.4519</td>
#       <td id="T_7983f_row0_col2" class="data row0 col2" >58.9768</td>
#       <td id="T_7983f_row0_col3" class="data row0 col3" >7.6796</td>
#       <td id="T_7983f_row0_col4" class="data row0 col4" >0.7899</td>
#       <td id="T_7983f_row0_col5" class="data row0 col5" >0.1971</td>
#       <td id="T_7983f_row0_col6" class="data row0 col6" >0.1286</td>
#       <td id="T_7983f_row0_col7" class="data row0 col7" >3.8325</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_7983f_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7983f_row1_col1" class="data row1 col1" >5.4700</td>
#       <td id="T_7983f_row1_col2" class="data row1 col2" >59.6567</td>
#       <td id="T_7983f_row1_col3" class="data row1 col3" >7.7237</td>
#       <td id="T_7983f_row1_col4" class="data row1 col4" >0.7875</td>
#       <td id="T_7983f_row1_col5" class="data row1 col5" >0.1982</td>
#       <td id="T_7983f_row1_col6" class="data row1 col6" >0.1292</td>
#       <td id="T_7983f_row1_col7" class="data row1 col7" >0.3050</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_7983f_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7983f_row2_col1" class="data row2 col1" >5.4825</td>
#       <td id="T_7983f_row2_col2" class="data row2 col2" >59.6317</td>
#       <td id="T_7983f_row2_col3" class="data row2 col3" >7.7221</td>
#       <td id="T_7983f_row2_col4" class="data row2 col4" >0.7876</td>
#       <td id="T_7983f_row2_col5" class="data row2 col5" >0.1980</td>
#       <td id="T_7983f_row2_col6" class="data row2 col6" >0.1294</td>
#       <td id="T_7983f_row2_col7" class="data row2 col7" >4.4450</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_7983f_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_7983f_row3_col1" class="data row3 col1" >5.4834</td>
#       <td id="T_7983f_row3_col2" class="data row3 col2" >61.4006</td>
#       <td id="T_7983f_row3_col3" class="data row3 col3" >7.8358</td>
#       <td id="T_7983f_row3_col4" class="data row3 col4" >0.7813</td>
#       <td id="T_7983f_row3_col5" class="data row3 col5" >0.1997</td>
#       <td id="T_7983f_row3_col6" class="data row3 col6" >0.1273</td>
#       <td id="T_7983f_row3_col7" class="data row3 col7" >6.9575</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_7983f_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_7983f_row4_col1" class="data row4 col1" >5.5210</td>
#       <td id="T_7983f_row4_col2" class="data row4 col2" >61.8099</td>
#       <td id="T_7983f_row4_col3" class="data row4 col3" >7.8619</td>
#       <td id="T_7983f_row4_col4" class="data row4 col4" >0.7798</td>
#       <td id="T_7983f_row4_col5" class="data row4 col5" >0.2010</td>
#       <td id="T_7983f_row4_col6" class="data row4 col6" >0.1293</td>
#       <td id="T_7983f_row4_col7" class="data row4 col7" >0.6400</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_7983f_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_7983f_row5_col1" class="data row5 col1" >5.5210</td>
#       <td id="T_7983f_row5_col2" class="data row5 col2" >61.8098</td>
#       <td id="T_7983f_row5_col3" class="data row5 col3" >7.8619</td>
#       <td id="T_7983f_row5_col4" class="data row5 col4" >0.7798</td>
#       <td id="T_7983f_row5_col5" class="data row5 col5" >0.2010</td>
#       <td id="T_7983f_row5_col6" class="data row5 col6" >0.1293</td>
#       <td id="T_7983f_row5_col7" class="data row5 col7" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_7983f_level0_row6" class="row_heading level0 row6" >omp</th>
#       <td id="T_7983f_row6_col0" class="data row6 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_7983f_row6_col1" class="data row6 col1" >5.5239</td>
#       <td id="T_7983f_row6_col2" class="data row6 col2" >61.1793</td>
#       <td id="T_7983f_row6_col3" class="data row6 col3" >7.8217</t

# %%
tuned_ = []
for each_top in top_:
    tuned_.append(tune_model(each_top, n_iter=100, optimize='MAE'))
# Out:
# <style type="text/css">
# #T_c2452_row4_col0, #T_c2452_row4_col1, #T_c2452_row4_col2, #T_c2452_row4_col3, #T_c2452_row4_col4, #T_c2452_row4_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c2452">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2452_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c2452_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c2452_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c2452_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c2452_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c2452_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2452_level0_row0" class="row_heading level0 row0" rowspan="6">CV-Val</th>
#       <th id="T_c2452_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_c2452_row0_col0" class="data row0 col0" >5.4555</td>
#       <td id="T_c2452_row0_col1" class="data row0 col1" >62.0647</td>
#       <td id="T_c2452_row0_col2" class="data row0 col2" >7.8781</td>
#       <td id="T_c2452_row0_col3" class="data row0 col3" >0.7762</td>
#       <td id="T_c2452_row0_col4" class="data row0 col4" >0.1982</td>
#       <td id="T_c2452_row0_col5" class="data row0 col5" >0.1247</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_c2452_row1_col0" class="data row1 col0" >5.4811</td>
#       <td id="T_c2452_row1_col1" class="data row1 col1" >62.0065</td>
#       <td id="T_c2452_row1_col2" class="data row1 col2" >7.8744</td>
#       <td id="T_c2452_row1_col3" class="data row1 col3" >0.7796</td>
#       <td id="T_c2452_row1_col4" class="data row1 col4" >0.1987</td>
#       <td id="T_c2452_row1_col5" class="data row1 col5" >0.1273</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_c2452_row2_col0" class="data row2 col0" >5.4417</td>
#       <td id="T_c2452_row2_col1" class="data row2 col1" >61.5825</td>
#       <td id="T_c2452_row2_col2" class="data row2 col2" >7.8475</td>
#       <td id="T_c2452_row2_col3" class="data row2 col3" >0.7799</td>
#       <td id="T_c2452_row2_col4" class="data row2 col4" >0.1956</td>
#       <td id="T_c2452_row2_col5" class="data row2 col5" >0.1229</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_c2452_row3_col0" class="data row3 col0" >5.4689</td>
#       <td id="T_c2452_row3_col1" class="data row3 col1" >62.2658</td>
#       <td id="T_c2452_row3_col2" class="data row3 col2" >7.8909</td>
#       <td id="T_c2452_row3_col3" class="data row3 col3" >0.7812</td>
#       <td id="T_c2452_row3_col4" class="data row3 col4" >0.2088</td>
#       <td id="T_c2452_row3_col5" class="data row3 col5" >0.1283</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level1_row4" class="row_heading level1 row4" >Mean</th>
#       <td id="T_c2452_row4_col0" class="data row4 col0" >5.4618</td>
#       <td id="T_c2452_row4_col1" class="data row4 col1" >61.9799</td>
#       <td id="T_c2452_row4_col2" class="data row4 col2" >7.8727</td>
#       <td id="T_c2452_row4_col3" class="data row4 col3" >0.7792</td>
#       <td id="T_c2452_row4_col4" class="data row4 col4" >0.2003</td>
#       <td id="T_c2452_row4_col5" class="data row4 col5" >0.1258</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level1_row5" class="row_heading level1 row5" >Std</th>
#       <td id="T_c2452_row5_col0" class="data row5 col0" >0.0147</td>
#       <td id="T_c2452_row5_col1" class="data row5 col1" >0.2488</td>
#       <td id="T_c2452_row5_col2" class="data row5 col2" >0.0158</td>
#       <td id="T_c2452_row5_col3" class="data row5 col3" >0.0018</td>
#       <td id="T_c2452_row5_col4" class="data row5 col4" >0.0050</td>
#       <td id="T_c2452_row5_col5" class="data row5 col5" >0.0021</td>
#     </tr>
#     <tr>
#       <th id="T_c2452_level0_row6" class="row_heading level0 row6" >Train</th>
#       <th id="T_c2452_level1_row6" class="row_heading level1 row6" >nan</th>
#       <td id="T_c2452_row6_col0" class="data row6 col0" >5.4615</td>
#       <td id="T_c2452_row6_col1" class="data row6 col1" >61.9821</td>
#       <td id="T_c2452_row6_col2" class="data row6 col2" >7.8729</td>
#       <td id="T_c2452_row6_col3" class="data row6 col3" >0.7792</td>
#       <td id="T_c2452_row6_col4" class="data row6 col4" >0.2002</td>
#       <td id="T_c2452_row6_col5" class="data row6 col5" >0.1257</td>
#     </tr>
#   </tbody>
# </table>

# %%
blended_ = blend_models(tuned_)
# Out:
# <style type="text/css">
# #T_bdcbf_row4_col0, #T_bdcbf_row4_col1, #T_bdcbf_row4_col2, #T_bdcbf_row4_col3, #T_bdcbf_row4_col4, #T_bdcbf_row4_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bdcbf">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdcbf_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bdcbf_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bdcbf_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bdcbf_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bdcbf_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bdcbf_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdcbf_level0_row0" class="row_heading level0 row0" rowspan="6">CV-Val</th>
#       <th id="T_bdcbf_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_bdcbf_row0_col0" class="data row0 col0" >5.4165</td>
#       <td id="T_bdcbf_row0_col1" class="data row0 col1" >59.0083</td>
#       <td id="T_bdcbf_row0_col2" class="data row0 col2" >7.6817</td>
#       <td id="T_bdcbf_row0_col3" class="data row0 col3" >0.7873</td>
#       <td id="T_bdcbf_row0_col4" class="data row0 col4" >0.1945</td>
#       <td id="T_bdcbf_row0_col5" class="data row0 col5" >0.1259</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_bdcbf_row1_col0" class="data row1 col0" >5.4445</td>
#       <td id="T_bdcbf_row1_col1" class="data row1 col1" >59.0208</td>
#       <td id="T_bdcbf_row1_col2" class="data row1 col2" >7.6825</td>
#       <td id="T_bdcbf_row1_col3" class="data row1 col3" >0.7902</td>
#       <td id="T_bdcbf_row1_col4" class="data row1 col4" >0.1951</td>
#       <td id="T_bdcbf_row1_col5" class="data row1 col5" >0.1288</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_bdcbf_row2_col0" class="data row2 col0" >5.4152</td>
#       <td id="T_bdcbf_row2_col1" class="data row2 col1" >58.7781</td>
#       <td id="T_bdcbf_row2_col2" class="data row2 col2" >7.6667</td>
#       <td id="T_bdcbf_row2_col3" class="data row2 col3" >0.7900</td>
#       <td id="T_bdcbf_row2_col4" class="data row2 col4" >0.1923</td>
#       <td id="T_bdcbf_row2_col5" class="data row2 col5" >0.1247</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_bdcbf_row3_col0" class="data row3 col0" >5.4505</td>
#       <td id="T_bdcbf_row3_col1" class="data row3 col1" >59.7064</td>
#       <td id="T_bdcbf_row3_col2" class="data row3 col2" >7.7270</td>
#       <td id="T_bdcbf_row3_col3" class="data row3 col3" >0.7902</td>
#       <td id="T_bdcbf_row3_col4" class="data row3 col4" >0.2059</td>
#       <td id="T_bdcbf_row3_col5" class="data row3 col5" >0.1303</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level1_row4" class="row_heading level1 row4" >Mean</th>
#       <td id="T_bdcbf_row4_col0" class="data row4 col0" >5.4317</td>
#       <td id="T_bdcbf_row4_col1" class="data row4 col1" >59.1284</td>
#       <td id="T_bdcbf_row4_col2" class="data row4 col2" >7.6895</td>
#       <td id="T_bdcbf_row4_col3" class="data row4 col3" >0.7894</td>
#       <td id="T_bdcbf_row4_col4" class="data row4 col4" >0.1970</td>
#       <td id="T_bdcbf_row4_col5" class="data row4 col5" >0.1274</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level1_row5" class="row_heading level1 row5" >Std</th>
#       <td id="T_bdcbf_row5_col0" class="data row5 col0" >0.0160</td>
#       <td id="T_bdcbf_row5_col1" class="data row5 col1" >0.3474</td>
#       <td id="T_bdcbf_row5_col2" class="data row5 col2" >0.0226</td>
#       <td id="T_bdcbf_row5_col3" class="data row5 col3" >0.0012</td>
#       <td id="T_bdcbf_row5_col4" class="data row5 col4" >0.0053</td>
#       <td id="T_bdcbf_row5_col5" class="data row5 col5" >0.0023</td>
#     </tr>
#     <tr>
#       <th id="T_bdcbf_level0_row6" class="row_heading level0 row6" >Train</th>
#       <th id="T_bdcbf_level1_row6" class="row_heading level1 row6" >nan</th>
#       <td id="T_bdcbf_row6_col0" class="data row6 col0" >5.3087</td>
#       <td id="T_bdcbf_row6_col1" class="data row6 col1" >56.1164</td>
#       <td id="T_bdcbf_row6_col2" class="data row6 col2" >7.4911</td>
#       <td id="T_bdcbf_row6_col3" class="data row6 col3" >0.8001</td>
#       <td id="T_bdcbf_row6_col4" class="data row6 col4" >0.1924</td>
#       <td id="T_bdcbf_row6_col5" class="data row6 col5" >0.1243</td>
#     </tr>
#   </tbody>
# </table>

# %%
finalized_ = finalize_model(blended_)

# %%
test['pred'] = (predict_model(finalized_, data=test)['Label']).round()

# Idea from https://www.kaggle.com/code/ambrosm/tpsmar22-generalizing-the-special-values

sep = train[(train.day >= 246) & (train.time >= 0)]
lower = sep.groupby(['time', 'x', 'y', 'direction']).congestion.quantile(0.15).values
upper = sep.groupby(['time', 'x', 'y', 'direction']).congestion.quantile(0.7).values

test.pred = test.pred.clip(lower, upper)

# for roadways with low value count replace prediction with nearest value from the training data

for xydir in set(test.xydir):
    
    xydir_counts = train.loc[train.xydir ==xydir,'congestion'].value_counts()
    
    l = xydir_counts[(xydir_counts > 200)] # experimental
    if len(l) > 2: # experimental
        l = list(l.index)
        test.loc[test.xydir ==xydir,'pred']= test.loc[test.xydir ==xydir,'pred'].map(lambda y: min(l, key=lambda x:abs(x-y)))

# %%
sub = pd.DataFrame(list(zip(test.index,test.pred.values)),columns = ['row_id', 'congestion'])

import datetime
now = datetime.datetime.now()
str_datetime = now.strftime("%y%m%d_%H%M%S")
sub.to_csv(DIR_DATASET+'submission-'+NAME_PROJECT+'-'+str_datetime+'.csv', index = 0)
sub.head()
# Out:
#    row_id  congestion
# 0  848835  50.0
# 1  848836  35.0
# 2  848837  53.0
# 3  848838  26.0
# 4  848839  71.0
